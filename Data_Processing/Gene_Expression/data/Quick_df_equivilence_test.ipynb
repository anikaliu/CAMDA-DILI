# %%
import pandas as pd
import glob

# %% [markdown]
# # GEXP metadata

# %% [markdown]
# ## pertiname

# %%
old = pd.read_csv("./GexClinical_pertiname.csv")
new = pd.read_csv("./GexClinical_pertiname_new.csv")

# %%
print(old.columns.values)
print(new.columns.values)
# Out:
# ['Unnamed: 0' 'x']
# ['LTKBID' 'PubChem_CID' 'Compound.Name' 'ApprovalYear' 'DILIConcern'
#  'Severity.Class' 'Label.Section' 'AdjudicatedDILI' 'vDILIConcern'
#  'Greene_Annotation' 'Sakatis_Annotation' 'Xu_Annotation' 'Zhu_Annotation'
#  'SMILES' 'URL..accessed.on.1.21.2016.' 'VER_DISP..1.LTKB.BD..2.others.'
#  'pert_iname']

# %%
old['x'].equals(new['Compound.Name'])
# Out:
# True

# %% [markdown]
# ## LINCS metadata

# %%
anika_meta = pd.read_csv("./LINCS_metadata.csv")
new = pd.read_csv("./GEXP_cdesc.csv")

# %%
print(anika_meta.columns.values)
del anika_meta['Unnamed: 0']
print(anika_meta.shape,new.shape)
# Out:
# ['Unnamed: 0' 'id' 'sig_id' 'pert_id' 'pert_iname' 'pert_type' 'cell_id'
#  'pert_dose' 'pert_dose_unit' 'pert_idose' 'pert_time' 'pert_time_unit'
#  'pert_itime' 'distil_id']
# (48468, 13) (48468, 13)

# %%
anika_meta.equals(new)
# Out:
# True

# %%
print(new.shape,new.columns.values)
new.head(5)
# Out:
# (48468, 13) ['id' 'sig_id' 'pert_id' 'pert_iname' 'pert_type' 'cell_id' 'pert_dose'
#  'pert_dose_unit' 'pert_idose' 'pert_time' 'pert_time_unit' 'pert_itime'
#  'distil_id']
#                                          id  \
# 0  CPC004_A375_6H:BRD-K20482099-001-01-1:10
# 1  CPC004_A375_6H:BRD-A14966924-001-03-0:10
# 2  CPC004_A375_6H:BRD-K79131256-001-08-8:10
# 3  CPC004_A375_6H:BRD-A90131694-001-02-8:10
# 4  CPC004_A375_6H:BRD-A09056319-001-05-5:10
#
#                                      sig_id        pert_id     pert_iname  \
# 0  CPC004_A375_6H:BRD-K20482099-001-01-1:10  BRD-K20482099          rutin
# 1  CPC004_A375_6H:BRD-A14966924-001-03-0:10  BRD-A14966924    alaproclate
# 2  CPC004_A375_6H:BRD-K79131256-001-08-8:10  BRD-K79131256    albendazole
# 3  CPC004_A375_6H:BRD-A90131694-001-02-8:10  BRD-A90131694  alclometasone
# 4  CPC004_A375_6H:BRD-A09056319-001-05-5:10  BRD-A09056319      alfuzosin
#
#   pert_type cell_id  pert_dose pert_dose_unit pert_idose  pert_time  \
# 0    trt_cp    A375       10.0             µM      10 µM          6
# 1    trt_cp    A375       10.0             µM      10 µM          6
# 2    trt_cp    A375       10.0             µM      10 µM          6
# 3    trt_cp    A375       10.0             µM      10 µM          6
# 4    trt_cp    A375       10.0             µM      10 µM          6
#
#   pert_time_unit pert_itime                                          distil_id
# 0              h        6 h  CPC004_A375_6H_X1_B3_DUO52HI53LO:K13|CPC004_A3...
# 1              h        6 h  CPC004_A375_6H_X1_B3_DUO52HI53LO:J04|CPC004_A3...
# 2              h        6 h  CPC004_A375_6H_X1_B3_DUO52HI53LO:H04|CPC004_A3...
# 3              h        6 h  CPC004_A375_6H_X1_B3_DUO52HI53LO:L22|CPC004_A3...
# 4              h        6 h  CPC004_A375_6H_X1_B3_DUO52HI53LO:H15|CPC004_A3...

# %% [markdown]
# ## LINCS metadata Peter July19

# %%
new_meta = pd.read_csv("./LINCS_DILI_metadata.csv")
print(new_meta.shape,new_meta.columns.values)
# Out:
# (7429, 31) ['Unnamed: 0' 'id' 'sig_id' 'pert_id' 'pert_iname' 'pert_type' 'cell_id'
#  'pert_dose' 'pert_dose_unit' 'pert_idose' 'pert_time' 'pert_time_unit'
#  'pert_itime' 'distil_id' 'n' 'LTKBID' 'PubChem_CID' 'Compound.Name'
#  'ApprovalYear' 'DILIConcern' 'Severity.Class' 'Label.Section'
#  'AdjudicatedDILI' 'vDILIConcern' 'Greene_Annotation' 'Sakatis_Annotation'
#  'Xu_Annotation' 'Zhu_Annotation' 'SMILES' 'URL..accessed.on.1.21.2016.'
#  'VER_DISP..1.LTKB.BD..2.others.']

# %%
new_meta.head(2)
# Out:
#    Unnamed: 0                                        id  \
# 0           1  CPC004_A375_6H:BRD-A14966924-001-03-0:10
# 1           2  CPC004_A375_6H:BRD-K79131256-001-08-8:10
#
#                                      sig_id        pert_id   pert_iname  \
# 0  CPC004_A375_6H:BRD-A14966924-001-03-0:10  BRD-A14966924  alaproclate
# 1  CPC004_A375_6H:BRD-K79131256-001-08-8:10  BRD-K79131256  albendazole
#
#   pert_type cell_id  pert_dose pert_dose_unit pert_idose  ...  \
# 0    trt_cp    A375         10             µM      10 µM  ...
# 1    trt_cp    A375         10             µM      10 µM  ...
#
#               Label.Section AdjudicatedDILI        vDILIConcern  \
# 0                 Withdrawn               .  vMost-DILI-Concern
# 1  Warnings and precautions             Yes  vMost-DILI-Concern
#
#   Greene_Annotation  Sakatis_Annotation Xu_Annotation  Zhu_Annotation  \
# 0                 .                   .             .               .
# 1                HH                   .      Positive         Postive
#
#                                SMILES  \
# 0  CC(C(=O)OC(C)(C)CC1=CC=C(C=C1)Cl)N
# 1   CCCSC1=CC2=C(C=C1)N=C(N2)NC(=O)OC
#
#                          URL..accessed.on.1.21.2016.  \
# 0                                                NaN
# 1  http://dailymed.nlm.nih.gov/dailymed/drugInfo....
#
#   VER_DISP..1.LTKB.BD..2.others.
# 0                              1
# 1                              2
#
# [2 rows x 31 columns]

# %%
old_peter_meta = pd.read_csv("./LINCS_metadata_Peter_July19.csv")
print(old_peter_meta.shape,old_peter_meta.columns.values)
old_peter_meta.head(2)
# Out:
# (7396, 31) ['Unnamed: 0' 'X' 'id' 'sig_id' 'pert_id' 'pert_iname' 'pert_type'
#  'cell_id' 'pert_dose' 'pert_dose_unit' 'pert_idose' 'pert_time'
#  'pert_time_unit' 'pert_itime' 'distil_id' 'LTKBID' 'PubChem_CID'
#  'Compound.Name' 'ApprovalYear' 'DILIConcern' 'Severity.Class'
#  'Label.Section' 'AdjudicatedDILI' 'vDILIConcern' 'Greene_Annotation'
#  'Sakatis_Annotation' 'Xu_Annotation' 'Zhu_Annotation' 'SMILES'
#  'URL..accessed.on.1.21.2016.' 'VER_DISP..1.LTKB.BD..2.others.']
#    Unnamed: 0      X                                        id  \
# 0           1  48292  CPC004_A375_6H:BRD-A14966924-001-03-0:10
# 1           2  48599  CPC004_A375_6H:BRD-K79131256-001-08-8:10
#
#                                      sig_id        pert_id   pert_iname  \
# 0  CPC004_A375_6H:BRD-A14966924-001-03-0:10  BRD-A14966924  alaproclate
# 1  CPC004_A375_6H:BRD-K79131256-001-08-8:10  BRD-K79131256  albendazole
#
#   pert_type cell_id  pert_dose pert_dose_unit  ...             Label.Section  \
# 0    trt_cp    A375         10             µM  ...                 Withdrawn
# 1    trt_cp    A375         10             µM  ...  Warnings and precautions
#
#    AdjudicatedDILI        vDILIConcern Greene_Annotation Sakatis_Annotation  \
# 0                .  vMost-DILI-Concern                 .                  .
# 1              Yes  vMost-DILI-Concern                HH                  .
#
#   Xu_Annotation  Zhu_Annotation                              SMILES  \
# 0             .               .  CC(C(=O)OC(C)(C)CC1=CC=C(C=C1)Cl)N
# 1      Positive         Postive   CCCSC1=CC2=C(C=C1)N=C(N2)NC(=O)OC
#
#                          URL..accessed.on.1.21.2016.  \
# 0                                                NaN
# 1  http://dailymed.nlm.nih.gov/dailymed/drugInfo....
#
#   VER_DISP..1.LTKB.BD..2.others.
# 0                              1
# 1                              2
#
# [2 rows x 31 columns]

# %%
old_peter_meta.columns.values.tolist() == new_meta.columns.values.tolist()
# Out:
# True

# %%
ne_stacked = (new_meta != old_peter_meta).stack()
ne_stacked[ne_stacked]
# Out:
# 0     Unnamed: 0                        True
#       id                                True
#       sig_id                            True
#       pert_id                           True
#       pert_iname                        True
#                                         ...
# 7428  Xu_Annotation                     True
#       Zhu_Annotation                    True
#       SMILES                            True
#       URL..accessed.on.1.21.2016.       True
#       VER_DISP..1.LTKB.BD..2.others.    True
# Length: 230227, dtype: bool

# %%
for col in new_meta.columns.values.tolist():

    ne_stacked = (new_meta[col] != old_peter_meta[col])#.stack()

    changed = ne_stacked[ne_stacked]
    print(col,changed.shape)
#changed.index.names = ['id', 'col']
# Out:
# Unnamed: 0 (0,)
# id (0,)
# sig_id (0,)
# pert_id (0,)
# pert_iname (0,)
# pert_type (0,)
# cell_id (0,)
# pert_dose (0,)
# pert_dose_unit (0,)
# pert_idose (0,)
# pert_time (0,)
# pert_time_unit (0,)
# pert_itime (0,)
# distil_id (0,)
# n (0,)
# LTKBID (0,)
# PubChem_CID (0,)
# Compound.Name (0,)
# ApprovalYear (0,)
# DILIConcern (0,)
# Severity.Class (0,)
# Label.Section (0,)
# AdjudicatedDILI (0,)
# vDILIConcern (0,)
# Greene_Annotation (0,)
# Sakatis_Annotation (0,)
# Xu_Annotation (0,)
# Zhu_Annotation (0,)
# SMILES (0,)
# URL..accessed.on.1.21.2016. (72,)
# VER_DISP..1.LTKB.BD..2.others. (0,)

# %%
conditions_with_GEXP_allcomps = pd.read_csv("./GEXP_comps_and_conditions_with_GEXP.csv")
print(conditions_with_GEXP_allcomps.shape)
# Out:
# (7429, 14)

# %%
print(conditions_with_GEXP_allcomps.columns.values)
conditions_with_GEXP_allcomps.head(2)
# Out:
# ['id' 'sig_id' 'pert_id' 'pert_iname' 'pert_type' 'cell_id' 'pert_dose'
#  'pert_dose_unit' 'pert_idose' 'pert_time' 'pert_time_unit' 'pert_itime'
#  'distil_id' 'n']
#                                          id  \
# 0  CPC004_A375_6H:BRD-A14966924-001-03-0:10
# 1  CPC004_A375_6H:BRD-K79131256-001-08-8:10
#
#                                      sig_id        pert_id   pert_iname  \
# 0  CPC004_A375_6H:BRD-A14966924-001-03-0:10  BRD-A14966924  alaproclate
# 1  CPC004_A375_6H:BRD-K79131256-001-08-8:10  BRD-K79131256  albendazole
#
#   pert_type cell_id  pert_dose pert_dose_unit pert_idose  pert_time  \
# 0    trt_cp    A375         10             µM      10 µM          6
# 1    trt_cp    A375         10             µM      10 µM          6
#
#   pert_time_unit pert_itime  \
# 0              h        6 h
# 1              h        6 h
#
#                                            distil_id    n
# 0  CPC004_A375_6H_X1_B3_DUO52HI53LO:J04|CPC004_A3...  233
# 1  CPC004_A375_6H_X1_B3_DUO52HI53LO:H04|CPC004_A3...  233

# %%
broad_id_smiles_map = pd.read_csv("./l1000_1314pert_inames.872matchedBROAD_ids.csv")
#broad_id_smiles_map = pd.read_csv("./l1000_1314pert_inames.872matchedBROAD_ids.tab",sep='\t')
print(broad_id_smiles_map.columns.values,broad_id_smiles_map.shape)
broad_id_smiles_map.head(2)
# Out:
# ['pert_iname' 'LTKBID' 'PubChem_CID' 'Compound.Name' 'ApprovalYear'
#  'DILIConcern' 'Severity.Class' 'Label.Section' 'AdjudicatedDILI'
#  'vDILIConcern' 'Greene_Annotation' 'Sakatis_Annotation' 'Xu_Annotation'
#  'Zhu_Annotation' 'SMILES' 'URL..accessed.on.1.21.2016.'
#  'VER_DISP..1.LTKB.BD..2.others.' 'BROAD_ID' 'CPD_NAME' 'CPD_NAME_TYPE'
#  'CPD_SAMPLE_ID' 'DOS_LIBRARY' 'SOURCE_NAME' 'CHEMIST_NAME'
#  'VENDOR_CATALOG_ID' 'CPD_SMILES' 'USERCOMMENT' 'pert_id'] (171, 28)
#     pert_iname   LTKBID  PubChem_CID Compound.Name ApprovalYear  \
# 0  albendazole  LT00499         2082   albendazole         1996
# 1    alfuzosin  LT01107         2092     alfuzosin         2003
#
#          DILIConcern  Severity.Class             Label.Section  \
# 0  Most-DILI-Concern               7  Warnings and precautions
# 1  Less-DILI-Concern               5         Adverse reactions
#
#   AdjudicatedDILI        vDILIConcern  ...     CPD_NAME CPD_NAME_TYPE  \
# 0             Yes  vMost-DILI-Concern  ...  albendazole           INN
# 1             Yes  vLess-DILI-Concern  ...    alfuzosin           INN
#
#   CPD_SAMPLE_ID DOS_LIBRARY                         SOURCE_NAME CHEMIST_NAME  \
# 0       SA58834         NaN  MicroSource Discovery Systems Inc.          NaN
# 1       SA83332         NaN             Prestwick Chemical Inc.          NaN
#
#    VENDOR_CATALOG_ID                                   CPD_SMILES USERCOMMENT  \
# 0            1503903               CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1         NaN
# 1         Prestw-322  COc1cc2nc(nc(N)c2cc1OC)N(C)CCCNC(=O)C1CCCO1         NaN
#
#          pert_id
# 0  BRD-K79131256
# 1  BRD-A09056319
#
# [2 rows x 28 columns]

# %%
result_df = pd.merge(new,broad_id_smiles_map,how='inner',left_on=['pert_id','pert_iname'], right_on=['pert_id','pert_iname'])

# %%
result_df.shape
# Out:
# (6354, 39)

# %%
broad_id_smiles_map = pd.read_csv("./l1000_1314pert_inames.872matchedBROAD_ids.csv")
#broad_id_smiles_map = pd.read_csv("./l1000_1314pert_inames.872matchedBROAD_ids.tab",sep='\t')
print(broad_id_smiles_map.columns.values)
broad_id_smiles_map.head(2)
#mapping = dict(broad_id_smiles_map[['pert_iname', 'pert_id']].values)
#DILIrank_meta['std_SMILES_protonated'] = meta['std_SMILES'].map(mapping)
# Out:
# ['pert_iname' 'LTKBID' 'PubChem_CID' 'Compound.Name' 'ApprovalYear'
#  'DILIConcern' 'Severity.Class' 'Label.Section' 'AdjudicatedDILI'
#  'vDILIConcern' 'Greene_Annotation' 'Sakatis_Annotation' 'Xu_Annotation'
#  'Zhu_Annotation' 'SMILES' 'URL..accessed.on.1.21.2016.'
#  'VER_DISP..1.LTKB.BD..2.others.' 'BROAD_ID' 'CPD_NAME' 'CPD_NAME_TYPE'
#  'CPD_SAMPLE_ID' 'DOS_LIBRARY' 'SOURCE_NAME' 'CHEMIST_NAME'
#  'VENDOR_CATALOG_ID' 'CPD_SMILES' 'USERCOMMENT' 'pert_id']
#     pert_iname   LTKBID  PubChem_CID Compound.Name ApprovalYear  \
# 0  albendazole  LT00499         2082   albendazole         1996
# 1    alfuzosin  LT01107         2092     alfuzosin         2003
#
#          DILIConcern  Severity.Class             Label.Section  \
# 0  Most-DILI-Concern               7  Warnings and precautions
# 1  Less-DILI-Concern               5         Adverse reactions
#
#   AdjudicatedDILI        vDILIConcern  ...     CPD_NAME CPD_NAME_TYPE  \
# 0             Yes  vMost-DILI-Concern  ...  albendazole           INN
# 1             Yes  vLess-DILI-Concern  ...    alfuzosin           INN
#
#   CPD_SAMPLE_ID DOS_LIBRARY                         SOURCE_NAME CHEMIST_NAME  \
# 0       SA58834         NaN  MicroSource Discovery Systems Inc.          NaN
# 1       SA83332         NaN             Prestwick Chemical Inc.          NaN
#
#    VENDOR_CATALOG_ID                                   CPD_SMILES USERCOMMENT  \
# 0            1503903               CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1         NaN
# 1         Prestw-322  COc1cc2nc(nc(N)c2cc1OC)N(C)CCCNC(=O)C1CCCO1         NaN
#
#          pert_id
# 0  BRD-K79131256
# 1  BRD-A09056319
#
# [2 rows x 28 columns]

# %%
#pd.merge(new,DILIrank_meta,how='inner',left_on=['pert_iname'], right_on=['Compound Name'])
pd.merge(new,broad_id_smiles_map,how='inner',left_on=['pert_id','pert_iname'], right_on=['pert_id','pert_iname'])
# Out:
#                                                id  \
# 0        CPC004_A375_6H:BRD-K79131256-001-08-8:10
# 1        CPC004_HA1E_6H:BRD-K79131256-001-08-8:10
# 2       CPC004_HA1E_24H:BRD-K79131256-001-08-8:10
# 3      CPC004_HCC515_6H:BRD-K79131256-001-08-8:10
# 4     CPC004_HCC515_24H:BRD-K79131256-001-08-8:10
# ...                                           ...
# 6349    CPC020_MCF7_24H:BRD-K93568044-001-24-7:10
# 6350      CPC020_PC3_6H:BRD-K93568044-001-24-7:10
# 6351     CPC020_PC3_24H:BRD-K93568044-001-24-7:10
# 6352     CPC020_VCAP_6H:BRD-K93568044-001-24-7:10
# 6353    CPC020_VCAP_24H:BRD-K93568044-001-24-7:10
#
#                                            sig_id        pert_id  \
# 0        CPC004_A375_6H:BRD-K79131256-001-08-8:10  BRD-K79131256
# 1        CPC004_HA1E_6H:BRD-K79131256-001-08-8:10  BRD-K79131256
# 2       CPC004_HA1E_24H:BRD-K79131256-001-08-8:10  BRD-K79131256
# 3      CPC004_HCC515_6H:BRD-K79131256-001-08-8:10  BRD-K79131256
# 4     CPC004_HCC515_24H:BRD-K79131256-001-08-8:10  BRD-K79131256
# ...                                           ...            ...
# 6349    CPC020_MCF7_24H:BRD-K93568044-001-24-7:10  BRD-K93568044
# 6350      CPC020_PC3_6H:BRD-K93568044-001-24-7:10  BRD-K93568044
# 6351     CPC020_PC3_24H:BRD-K93568044-001-24-7:10  BRD-K93568044
# 6352     CPC020_VCAP_6H:BRD-K93568044-001-24-7:10  BRD-K93568044
# 6353    CPC020_VCAP_24H:BRD-K93568044-001-24-7:10  BRD-K93568044
#
#           pert_iname pert_type cell_id  pert_dose pert_dose_unit pert_idose  \
# 0        albendazole    trt_cp    A375       10.0             µM      10 µM
# 1        albendazole    trt_cp    HA1E       10.0             µM      10 µM
# 2        albendazole    trt_cp    HA1E       10.0             µM      10 µM
# 3        albendazole    trt_cp  HCC515       10.0             µM      10 µM
# 4        albendazole    trt_cp  HCC515       10.0             µM      10 µM
# ...              ...       ...     ...        ...            ...        ...
# 6349  hydrocortisone    trt_cp    MCF7       10.0             µM      10 µM
# 6350  hydrocortisone    trt_cp     PC3       10.0             µM      10 µM
# 6351  hydrocortisone    trt_cp     PC3       10.0             µM      10 µM
# 6352  hydrocortisone    trt_cp    VCAP       10.0             µM      10 µM
# 6353  hydrocortisone    trt_cp    VCAP       10.0             µM      10 µM
#
#       pert_time  ...                BROAD_ID        CPD_NAME CPD_NAME_TYPE  \
# 0             6  ...  BRD-K79131256-001-03-9     albendazole           INN
# 1             6  ...  BRD-K79131256-001-03-9     albendazole           INN
# 2            24  ...  BRD-K79131256-001-03-9     albendazole           INN
# 3             6  ...  BRD-K79131256-001-03-9     albendazole           INN
# 4            24  ...  BRD-K79131256-001-03-9     albendazole           INN
# ...         ...  ...                     ...             ...           ...
# 6349         24  ...  BRD-K93568044-001-03-1  hydrocortisone           INN
# 6350          6  ...  BRD-K93568044-001-03-1  hydrocortisone           INN
# 6351         24  ...  BRD-K93568044-001-03-1  hydrocortisone           INN
# 6352          6  ...  BRD-K93568044-001-03-1  hydrocortisone           INN
# 6353         24  ...  BRD-K93568044-001-03-1  hydrocortisone           INN
#
#      CPD_SAMPLE_ID  DOS_LIBRARY                         SOURCE_NAME  \
# 0          SA58834          NaN  MicroSource Discovery Systems Inc.
# 1          SA58834          NaN  MicroSource Discovery Systems Inc.
# 2          SA58834          NaN  MicroSource Discovery Systems Inc.
# 3          SA58834          NaN  MicroSource Discovery Systems Inc.
# 4          SA58834          NaN  MicroSource Discovery Systems Inc.
# ...            ...          ...                                 ...
# 6349       SA82968          NaN             Prestwick Chemical Inc.
# 6350       SA82968          NaN             Prestwick Chemical Inc.
# 6351       SA82968          NaN             Prestwick Chemical Inc.
# 6352       SA82968          NaN             Prestwick Chemical Inc.
# 6353       SA82968          NaN             Prestwick Chemical Inc.
#
#      CHEMIST_NAME VENDOR_CATALOG_ID  \
# 0             NaN           1503903
# 1             NaN           1503903
# 2             NaN           1503903
# 3             NaN           1503903
# 4             NaN           1503903
# ...           ...               ...
# 6349          NaN        Prestw-447
# 6350          NaN        Prestw-447
# 6351          NaN        Prestw-447
# 6352          NaN        Prestw-447
# 6353          NaN        Prestw-447
#
#                                              CPD_SMILES USERCOMMENT
# 0                        CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1         NaN
# 1                        CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1         NaN
# 2                        CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1         NaN
# 3                        CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1         NaN
# 4                        CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1         NaN
# ...                                                 ...         ...
# 6349  C[C@]12C[C@H](O)[C@H]3[C@@H](CCC4=CC(=O)CC[C@]...         NaN
# 6350  C[C@]12C[C@H](O)[C@H]3[C@@H](CCC4=CC(=O)CC[C@]...         NaN
# 6351  C[C@]12C[C@H](O)[C@H]3[C@@H](CCC4=CC(=O)CC[C@]...         NaN
# 6352  C[C@]12C[C@H](O)[C@H]3[C@@H](CCC4=CC(=O)CC[C@]...         NaN
# 6353  C[C@]12C[C@H](O)[C@H]3[C@@H](CCC4=CC(=O)CC[C@]...         NaN
#
# [6354 rows x 39 columns]

# %% [markdown]
# # Input files to GEXP models

# %%
filelist1 = []
for file in glob.glob( "./Cell_line_Training_Data/*.csv" ) :
    print(file)
    filelist1.append(file)
# Out:
# ./Cell_line_Training_Data/('SKB', 24, 10).csv
# ./Cell_line_Training_Data/('VCAP', 6, 10).csv
# ./Cell_line_Training_Data/('A375', 6, 10).csv
# ./Cell_line_Training_Data/All_Cell_Lines.csv
# ./Cell_line_Training_Data/('HA1E', 6, 10).csv
# ./Cell_line_Training_Data/('MCF7', 24, 10).csv
# ./Cell_line_Training_Data/('ASC', 24, 10).csv
# ./Cell_line_Training_Data/('HCC515', 6, 10).csv
# ./Cell_line_Training_Data/('A549', 24, 10).csv
# ./Cell_line_Training_Data/('HEPG2', 6, 10).csv
# ./Cell_line_Training_Data/('PHH', 24, 10).csv
# ./Cell_line_Training_Data/('MCF7', 6, 10).csv
# ./Cell_line_Training_Data/('PC3', 6, 10).csv
# ./Cell_line_Training_Data/('PC3', 24, 10).csv
# ./Cell_line_Training_Data/('HT29', 6, 10).csv

# %%
filelist2 = []
for file in glob.glob( "./Cell_line_Training_Data_new/*.csv" ) :
    print(file)
    filelist2.append(file)
# Out:
# ./Cell_line_Training_Data_new/('SKB', 24, 10).csv
# ./Cell_line_Training_Data_new/('VCAP', 6, 10).csv
# ./Cell_line_Training_Data_new/('A375', 6, 10).csv
# ./Cell_line_Training_Data_new/All_Cell_Lines.csv
# ./Cell_line_Training_Data_new/('HA1E', 6, 10).csv
# ./Cell_line_Training_Data_new/('MCF7', 24, 10).csv
# ./Cell_line_Training_Data_new/('ASC', 24, 10).csv
# ./Cell_line_Training_Data_new/('HCC515', 6, 10).csv
# ./Cell_line_Training_Data_new/('A549', 24, 10).csv
# ./Cell_line_Training_Data_new/('HEPG2', 6, 10).csv
# ./Cell_line_Training_Data_new/('PHH', 24, 10).csv
# ./Cell_line_Training_Data_new/('MCF7', 6, 10).csv
# ./Cell_line_Training_Data_new/('PC3', 6, 10).csv
# ./Cell_line_Training_Data_new/('PC3', 24, 10).csv
# ./Cell_line_Training_Data_new/('HT29', 6, 10).csv

# %%
for f, b in zip(filelist1, filelist2):
    print(f, b)
    original = pd.read_csv(f)
    new = pd.read_csv(b)
    print(original.equals(new))
# Out:
# ./Cell_line_Training_Data/('SKB', 24, 10).csv ./Cell_line_Training_Data_new/('SKB', 24, 10).csv
# False
# ./Cell_line_Training_Data/('VCAP', 6, 10).csv ./Cell_line_Training_Data_new/('VCAP', 6, 10).csv
# False
# ./Cell_line_Training_Data/('A375', 6, 10).csv ./Cell_line_Training_Data_new/('A375', 6, 10).csv
# False
# ./Cell_line_Training_Data/All_Cell_Lines.csv ./Cell_line_Training_Data_new/All_Cell_Lines.csv
# False
# ./Cell_line_Training_Data/('HA1E', 6, 10).csv ./Cell_line_Training_Data_new/('HA1E', 6, 10).csv
# False
# ./Cell_line_Training_Data/('MCF7', 24, 10).csv ./Cell_line_Training_Data_new/('MCF7', 24, 10).csv
# False
# ./Cell_line_Training_Data/('ASC', 24, 10).csv ./Cell_line_Training_Data_new/('ASC', 24, 10).csv
# False
# ./Cell_line_Training_Data/('HCC515', 6, 10).csv ./Cell_line_Training_Data_new/('HCC515', 6, 10).csv
# False
# ./Cell_line_Training_Data/('A549', 24, 10).csv ./Cell_line_Training_Data_new/('A549', 24, 10).csv
# False
# ./Cell_line_Training_Data/('HEPG2', 6, 10).csv ./Cell_line_Training_Data_new/('HEPG2', 6, 10).csv
# False
# ./Cell_line_Training_Data/('PHH', 24, 10).csv ./Cell_line_Training_Data_new/('PHH', 24, 10).csv
# False
# ./Cell_line_Training_Data/('MCF7', 6, 10).csv ./Cell_line_Training_Data_new/('MCF7', 6, 10).csv
# False
# ./Cell_line_Training_Data/('PC3', 6, 10).csv ./Cell_line_Training_Data_new/('PC3', 6, 10).csv
# False
# ./Cell_line_Training_Data/('PC3', 24, 10).csv ./Cell_line_Training_Data_new/('PC3', 24, 10).csv
# False
# ./Cell_line_Training_Data/('HT29', 6, 10).csv ./Cell_line_Training_Data_new/('HT29', 6, 10).csv
# False
