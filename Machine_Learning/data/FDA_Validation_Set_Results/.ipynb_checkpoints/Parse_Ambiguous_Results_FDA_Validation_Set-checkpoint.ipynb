# %%
import glob, os
from sklearn.metrics import classification_report
import numpy as np
import pandas as pd


directories = ['../data/Predictions_ECFP4','../data/Predictions_MD','../data/Predictions_PT']

# %%
def metrics_func(TP,FP,FN,TN):

    
    if TN == 0:
        specificity=0
        recall = TP/(TP+FN)
        precision = TP/(TP+FP)
        if (TN+FN) == 0:
            MCC = 0
        else:
            MCC = (TP*TN - FP*FN)/(np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)))

        
    elif TP == 0:
        precision = 0
        recall=0
        specificity = TN/(TN+FP)
        if (FP+TP) == 0:
            MCC = 0
        else:
            MCC = (TP*TN - FP*FN)/(np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)))


        
#    elif (TN+FN) ==0 or (FP+TP) == 0:
#        MCC=0
        
    else:
        specificity = TN/(TN+FP)
        recall = TP/(TP+FN)
        MCC = (TP*TN - FP*FN)/(np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)))
        precision = TP/(TP+FP)
    
    
    balanced_accuracy = (specificity+recall)/2
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    
    return precision,recall,specificity,balanced_accuracy,accuracy,MCC

# %%
faulty_file_dirs = []
for result_dir in directories:
    #df = pd.DataFrame(data=None, columns=['model','precision','recall','balanced_accuracy','MCC'])
    list_of_lists = []
    for file in os.listdir(result_dir):
        if file.endswith(".txt"):
            print(os.path.join(result_dir, file))
            f = open(os.path.join(result_dir, file), 'r')
            try:

                content = [line.rstrip('\n') for line in f]
                print(content)
                
                
                size=sum(1 for _ in content)
                print(size)
                
                
                print(type(content[1].split(",")[0]),content[1].split(",")[0])
                
                p = content[1].split(",")[0].replace('"', '')
                print(p)
                if p == str("1"): # if never predicted 0 missing line
                    print("wow1")
                    TN = 0
                    FN = 0
                    FP = int(content[1].split(",")[1])
                    TP = int(content[1].split(",")[2])
                    
                elif p == str("0") and size == 2 : # if never predicted 1
                    print("wow2")
                    TN = int(content[1].split(",")[1])
                    FN = int(content[1].split(",")[2])
                    FP = 0
                    TP = 0
                    print(TN,FN,FP,TP)

                else:

                    TN = int(content[1].split(",")[1])
                    FN = int(content[1].split(",")[2])
                    FP = int(content[2].split(",")[1])
                    TP = int(content[2].split(",")[2])


                p,r,sen,ba,a,mcc = metrics_func(TP,FP,FN,TN)

                list_of_lists.append([file,p,r,sen,ba,a,mcc])
                
            except:
                print('ERROR')
                break
                
                faulty_file_dirs.append(os.path.join(result_dir, file))
                list_of_lists.append([file,None,None,None,None,None,None])
                
            finally:
                f.close()
    df = pd.DataFrame(list_of_lists,columns=['model','precision','recall','specificity','balanced_accuracy','accuracy','MCC'])
    df['model'] = df['model'].str[4:]
    df['model'] = df['model'].str[:-4]
    df.replace('_', '.', regex=True, inplace=True)
    #df['model'] = df['model'].replace("_", ".")
    df.rename(columns={"model": "splits"},inplace=True)
    df.to_csv(result_dir+"/ambiguous_results.csv")
# Out:
# ./Predictions_ECFP4/val.MCLCNC_SVM_1_7.txt
# ['"0","1"', '"0",13,5', '"1",19,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_ECFP4/val.all_RF_1_1.txt
# ['"0","1"', '"0",16,4', '"1",16,13']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_ECFP4/val.all_SVM_1_10.txt
# ['"0","1"', '"0",14,6', '"1",18,11']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_ECFP4/val.MCLCNC_SVM_1_6.txt
# ['"0","1"', '"0",13,5', '"1",19,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_ECFP4/val.MCLCNC_SVM_1_4.txt
# ['"0","1"', '"0",13,5', '"1",19,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_ECFP4/val.all_RF_1_2.txt
# ['"0","1"', '"0",15,3', '"1",17,14']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_ECFP4/val.all_RF_1
12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_RF_1_4.txt
# ['"0","1"', '"0",22,8', '"1",10,9']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_RF_1_5.txt
# ['"0","1"', '"0",22,11', '"1",10,6']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_SVM_1_1.txt
# ['"0","1"', '"0",16,7', '"1",16,10']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_9.txt
# ['"0","1"', '"0",0,0', '"1",32,17']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_8.txt
# ['"0","1"', '"0",10,6', '"1",22,11']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_SVM_1_5.txt
# ['"0","1"', '"0",15,5', '"1",17,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_RF_1_1.txt
# ['"0","1"', '"0",22,8', '"1",10,9']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_SVM_1_4.txt
# ['"0","1"', '"0",15,5', '"1",17,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_9.txt
# ['"0","1"', '"0",10,5', '"1",22,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_8.txt
# ['"0","1"', '"0",1,0', '"1",31,17']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_SVM_1_6.txt
# ['"0","1"', '"0",15,4', '"1",17,13']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_RF_1_2.txt
# ['"0","1"', '"0",23,10', '"1",9,7']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_RF_1_3.txt
# ['"0","1"', '"0",24,10', '"1",8,7']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_SVM_1_7.txt
# ['"0","1"', '"0",16,7', '"1",16,10']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_6.txt
# ['"0","1"', '"0",0,0', '"1",32,17']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_7.txt
# ['"0","1"', '"0",9,6', '"1",23,11']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_6.txt
# ['"0","1"', '"0",10,5', '"1",22,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_7.txt
# ['"0","1"', '"0",0,0', '"1",32,17']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_5.txt
# ['"0","1"', '"0",0,1', '"1",32,16']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_4.txt
# ['"0","1"', '"0",10,5', '"1",22,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_SVM_1_9.txt
# ['"0","1"', '"0",15,5', '"1",17,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_SVM_1_8.txt
# ['"0","1"', '"0",16,7', '"1",16,10']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_5.txt
# ['"0","1"', '"0",10,5', '"1",22,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_4.txt
# ['"0","1"', '"0",1,0', '"1",31,17']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_SVM_1_10.txt
# ['"0","1"', '"0",16,7', '"1",16,10']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_1.txt
# ['"0","1"', '"0",11,4', '"1",21,13']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_RF_1_8.txt
# ['"0","1"', '"0",23,7', '"1",9,10']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_RF_1_9.txt
# ['"0","1"', '"0",24,10', '"1",8,7']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_1.txt
# ['"0","1"', '"0",0,1', '"1",32,16']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCNC_RF_1_10.txt
# ['"0","1"', '"0",24,10', '"1",8,7']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_3.txt
# ['"0","1"', '"0",0,1', '"1",32,16']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_2.txt
# ['"0","1"', '"0",10,6', '"1",22,11']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_SVM_1_3.txt
# ['"0","1"', '"0",10,6', '"1",22,11']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_2.txt
# ['"0","1"', '"0",0,0', '"1",32,17']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_RF_1_8.txt
# ['"0","1"', '"0",10,5', '"1",22,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.all_RF_1_9.txt
# ['"0","1"', '"0",10,5', '"1",22,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_SVM_1_10.txt
# ['"0","1"', '"0",9,5', '"1",23,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_RF_1_10.txt
# ['"0","1"', '"0",0,1', '"1",32,16']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_SVM_1_8.txt
# ['"0","1"', '"0",8,5', '"1",24,12']
# 3
# <class 'str'> "0"
# 0
# ./Predictions_PT/val.MCLCNC_SVM_1_9.txt
# ['"0","1"', '"0",9,5', '"1",23,12']
# 3
# <class 'str'> "0"
# 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-8c0451a3114c> in <module>
#       3     #df = pd.DataFrame(data=None, columns=['model','precision','recall','balanced_accuracy','MCC'])
#       4     list_of_lists = []
# ----> 5     for file in os.listdir(result_dir):
#       6         if file.endswith(".txt"):
#       7             print(os.path.join(result_dir, file))
#
# FileNotFoundError: [Errno 2] No such file or directory: './Anika_ECFP_red'

# %%
faulty_file_dirs
# Out:
# []

# %%
df
# Out:
#              splits  precision    recall  specificity  balanced_accuracy  \
# 0    MCLCNC.SVM.1.7   0.361111  0.764706      0.28125           0.522978
# 1        all.RF.1.1   0.307692  0.470588      0.43750           0.454044
# 2      all.SVM.1.10   0.333333  0.647059      0.31250           0.479779
# 3    MCLCNC.SVM.1.6   0.333333  0.764706      0.18750           0.476103
# 4    MCLCNC.SVM.1.4   0.342857  0.705882      0.28125           0.493566
# 5        all.RF.1.2   0.370370  0.588235      0.46875           0.528493
# 6        all.RF.1.3   0.333333  0.588235      0.37500           0.481618
# 7    MCLCNC.SVM.1.5   0.342105  0.764706      0.21875           0.491728
# 8    MCLCNC.SVM.1.1   0.342105  0.764706      0.21875           0.491728
# 9        all.RF.1.7   0.320000  0.470588      0.46875           0.469669
# 10       all.RF.1.6   0.333333  0.529412      0.43750           0.483456
# 11   MCLCNC.SVM.1.2   0.361111  0.764706      0.28125           0.522978
# 12       all.RF.1.4   0.312500  0.588235      0.31250           0.450368
# 13       all.RF.1.5   0.321429  0.529412      0.40625           0.467831
# 14   MCLCNC.SVM.1.3   0.361111  0.764706      0.28125           0.522978
# 15     MCNC.SVM.1.3   0.433333  0.764706      0.46875           0.616728
# 16      MCNC.RF.1.7   0.538462  0.411765      0.81250           0.612132
# 17      MCNC.RF.1.6   0.466667  0.411765      0.75000           0.580882
# 18     MCNC.SVM.1.2   0.413793  0.705882      0.46875           0.587316
# 19      all.RF.1.10   0.387097  0.705882      0.40625           0.556066
# 20      MCNC.RF.1.4   0.473684  0.529412      0.68750           0.608456
# 21      MCNC.RF.1.5   0.375000  0.352941      0.68750           0.520221
# 22     MCNC.SVM.1.1   0.384615  0.588235      0.50000           0.544118
# 23    MCLCNC.RF.1.9   0.346939  1.000000      0.00000           0.500000
# 24      all.SVM.1.8   0.333333  0.647059      0.31250           0.479779
# 25     MCNC.SVM.1.5   0.413793  0.705882      0.46875           0.587316
# 26      MCNC.RF.1.1   0.473684  0.529412      0.68750           0.608456
# 27     MCNC.SVM.1.4   0.413793  0.705882      0.46875           0.587316
# 28      all.SVM.1.9   0.352941  0.705882      0.31250           0.509191
# 29    MCLCNC.RF.1.8   0.354167  1.000000      0.03125           0.515625
# 30     MCNC.SVM.1.6   0.433333  0.764706      0.46875           0.616728
# 31      MCNC.RF.1.2   0.437500  0.411765      0.71875           0.565257
# 32      MCNC.RF.1.3   0.466667  0.411765      0.75000           0.580882
# 33     MCNC.SVM.1.7   0.384615  0.588235      0.50000           0.544118
# 34    MCLCNC.RF.1.6   0.346939  1.000000      0.00000           0.500000
# 35      all.SVM.1.7   0.323529  0.647059      0.28125           0.464154
# 36      all.SVM.1.6   0.352941  0.705882      0.31250           0.509191
# 37    MCLCNC.RF.1.7   0.346939  1.000000      0.00000           0.500000
# 38    MCLCNC.RF.1.5   0.333333  0.941176      0.00000           0.470588
# 39      all.SVM.1.4   0.352941  0.705882      0.31250           0.509191
# 40     MCNC.SVM.1.9   0.413793  0.705882      0.46875           0.587316
# 41     MCNC.SVM.1.8   0.384615  0.588235      0.50000           0.544118
# 42      all.SVM.1.5   0.352941  0.705882      0.31250           0.509191
# 43    MCLCNC.RF.1.4   0.354167  1.000000      0.03125           0.515625
# 44    MCNC.SVM.1.10   0.384615  0.588235      0.50000           0.544118
# 45      all.SVM.1.1   0.382353  0.764706      0.34375           0.554228
# 46      MCNC.RF.1.8   0.526316  0.588235      0.71875           0.653493
# 47      MCNC.RF.1.9   0.466667  0.411765      0.75000           0.580882
# 48    MCLCNC.RF.1.1   0.333333  0.941176      0.00000           0.470588
# 49     MCNC.RF.1.10   0.466667  0.411765      0.75000           0.580882
# 50    MCLCNC.RF.1.3   0.333333  0.941176      0.00000           0.470588
# 51      all.SVM.1.2   0.333333  0.647059      0.31250           0.479779
# 52      all.SVM.1.3   0.333333  0.647059      0.31250           0.479779
# 53    MCLCNC.RF.1.2   0.346939  1.000000      0.00000           0.500000
# 54       all.RF.1.8   0.352941  0.705882      0.31250           0.509191
# 55       all.RF.1.9   0.352941  0.705882      0.31250           0.509191
# 56  MCLCNC.SVM.1.10   0.342857  0.705882      0.28125           0.493566
# 57   MCLCNC.RF.1.10   0.333333  0.941176      0.00000           0.470588
# 58   MCLCNC.SVM.1.8   0.333333  0.705882      0.25000           0.477941
# 59   MCLCNC.SVM.1.9   0.342857  0.705882      0.28125           0.493566
#
#     accuracy       MCC
# 0   0.448980  0.049547
# 1   0.448980 -0.087664
# 2   0.428571 -0.041049
# 3   0.387755 -0.056447
# 4   0.428571 -0.013558
# 5   0.510204  0.054534
# 6   0.448980 -0.035916
# 7   0.408163 -0.018874
# 8   0.408163 -0.018874
# 9   0.469388 -0.057762
# 10  0.469388 -0.031665
# 11  0.448980  0.049547
# 12  0.408163 -0.099265
# 13  0.448980 -0.061884
# 14  0.448980  0.049547
# 15  0.571429  0.228069
# 16  0.673469  0.241790
# 17  0.632653  0.167070
# 18  0.551020  0.169126
# 19  0.510204  0.110717
# 20  0.632653  0.211907
# 21  0.571429  0.041049
# 22  0.530612  0.084157
# 23  0.346939  0.000000
# 24  0.428571 -0.041049
# 25  0.551020  0.169126
# 26  0.632653  0.211907
# 27  0.551020  0.169126
# 28  0.448980  0.018985
# 29  0.367347  0.105203
# 30  0.571429  0.228069
# 31  0.612245  0.132477
# 32  0.632653  0.167070
# 33  0.530612  0.084157
# 34  0.346939  0.000000
# 35  0.408163 -0.074042
# 36  0.448980  0.018985
# 37  0.346939  0.000000
# 38  0.326531 -0.198030
# 39  0.448980  0.018985
# 40  0.551020  0.169126
# 41  0.530612  0.084157
# 42  0.448980  0.018985
# 43  0.367347  0.105203
# 44  0.530612  0.084157
# 45  0.489796  0.112013
# 46  0.673469  0.299902
# 47  0.632653  0.167070
# 48  0.326531 -0.198030
# 49  0.632653  0.167070
# 50  0.326531 -0.198030
# 51  0.428571 -0.041049
# 52  0.428571 -0.041049
# 53  0.346939  0.000000
# 54  0.448980  0.018985
# 55  0.448980  0.018985
# 56  0.428571 -0.013558
# 57  0.326531 -0.198030
# 58  0.408163 -0.047565
# 59  0.428571 -0.013558
