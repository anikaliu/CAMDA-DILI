# %%
import pandas as pd
import numpy as np
import glob, os
import pickle

# %%
os.chdir('./Models')

# %%
print(os.getcwd())
# Out:
# /Users/psrw2/OneDrive - University Of Cambridge/CAMBA_Competition/CAMDA-DILI-master_19_08_19/processed_data/Models

# %%
directories = ['./ECFP','./ECFP_red','./MD','./MD_red','./PT','./PT_red']

# %%
models = []
RF_cv = []
RF_test = {}
SVM_cv = []
SVM_test = {}
i=0
for file in glob.glob('./**/cv_scores*'):
    model = file.split('/')[1]
    print(model)
    CV_data = pd.read_csv(file)
    #print(CV_data)
    RF_models_cv = CV_data[CV_data['splits'].str.contains("MCNC.RF.1" + "\.")]
    SVM_models_cv = CV_data[CV_data['splits'].str.contains("MCNC.SVM.1" + "\.")]
    


    RF_test['RF_'+model+'_internal_cv'] = [str(round(RF_models_cv.mean(axis=0)[i],3)) +"\u00B1"+ str(round(RF_models_cv.std(axis=0)[i],3)) for i in range(len(RF_models_cv.median(axis=0)))]
    SVM_test['SVM_'+model+'_internal_cv'] = [str(round(SVM_models_cv.mean(axis=0)[i],3)) +"\u00B1"+ str(round(SVM_models_cv.std(axis=0)[i],3)) for i in range(len(SVM_models_cv.median(axis=0)))]
    
    
i=0
for file in glob.glob('./**/ts_scores*'):
    model = file.split('/')[1]
    print(model)
    Test_data = pd.read_csv(file)
    


    
    
    RF_models_ts = Test_data[Test_data['splits'].str.contains("MCNC.RF.1" + "\.")]
    SVM_models_ts = Test_data[Test_data['splits'].str.contains("MCNC.SVM.1" + "\.")]

    
    RF_test['RF_'+model+'_internal_test'] = [str(round(RF_models_ts.mean(axis=0)[i],3)) +"\u00B1"+ str(round(RF_models_ts.std(axis=0)[i],3)) for i in range(len(RF_models_ts.median(axis=0)))] 
    SVM_test['SVM_'+model+'_internal_test'] = [str(round(SVM_models_ts.mean(axis=0)[i],3)) +"\u00B1"+ str(round(SVM_models_ts.std(axis=0)[i],3)) for i in range(len(SVM_models_ts.median(axis=0)))]
# Out:
# MD_red
# ECFP_red
# PT
# PT_red
# MD
# ECFP
# MD_red
# ECFP_red
# PT
# PT_red
# MD
# ECFP

# %%
SVM_test
# Out:
# {'SVM_MD_red_internal_cv': ['0.601±0.123',
#   '0.591±0.124',
#   '0.523±0.194',
#   '0.532±0.187',
#   '0.539±0.175',
#   '0.561±0.169',
#   '0.181±0.25'],
#  'SVM_ECFP_red_internal_cv': ['0.66±0.134',
#   '0.647±0.138',
#   '0.505±0.237',
#   '0.633±0.233',
#   '0.616±0.224',
#   '0.66±0.189',
#   '0.308±0.282'],
#  'SVM_PT_internal_cv': ['0.728±0.049',
#   '0.728±0.048',
#   '0.725±0.088',
#   '0.68±0.08',
#   '0.765±0.072',
#   '0.793±0.056',
#   '0.457±0.097'],
#  'SVM_PT_red_internal_cv': ['0.639±0.107',
#   '0.624±0.116',
#   '0.496±0.234',
#   '0.604±0.201',
#   '0.654±0.185',
#   '0.662±0.172',
#   '0.261±0.231'],
#  'SVM_MD_internal_cv': ['0.648±0.064',
#   '0.643±0.063',
#   '0.609±0.099',
#   '0.595±0.077',
#   '0.599±0.088',
#   '0.674±0.07',
#   '0.287±0.127'],
#  'SVM_ECFP_internal_cv': ['0.717±0.058',
#   '0.714±0.058',
#   '0.697±0.078',
#   '0.671±0.075',
#   '0.712±0.083',
#   '0.769±0.063',
#   '0.429±0.116'],
#  'SVM_MD_red_internal_test': ['0.617±0.095',
#   '0.603±0.096',
#   '0.5±0.152',
#   '0.55±0.112',
#   '0.52±0.164',
#   '0.57±0.197',
#   '0.209±0.195'],
#  'SVM_ECFP_red_internal_test': ['0.627±0.179',
#   '0.614±0.179',
#   '0.525±0.286',
#   '0.6±0.23',
#   '0.675±0.197',
#   '0.738±0.198',
#   '0.248±0.368'],
#  'SVM_PT_internal_test': ['0.757±0.042',
#   '0.753±0.039',
#   '0.722±0.076',
#   '0.727±0.073',
#   '0.815±0.062',
#   '0.837±0.043',
#   '0.511±0.081'],
#  'SVM_PT_red_internal_test': ['0.616±0.189',
#   '0.608±0.192',
#   '0.55±0.294',
#   '0.596±0.272',
#   '0.657±0.201',
#   '0.668±0.22',
#   '0.238±0.393'],
#  'SVM_MD_internal_test': ['0.701±0.069',
#   '0.695±0.068',
#   '0.649±0.082',
#   '0.662±0.093',
#   '0.644±0.11',
#   '0.718±0.064',
#   '0.393±0.14'],
#  'SVM_ECFP_internal_test': ['0.763±0.026',
#   '0.759±0.027',
#   '0.724±0.084',
#   '0.736±0.056',
#   '0.778±0.065',
#   '0.824±0.034',
#   '0.523±0.054']}

# %%
pd.DataFrame.from_dict(RF_test,orient='index', columns=['accuracy','balanced_accuracy','recall','precision','AU_Prec_Rec_Curve','ROC_AUC','MCC'])#
# Out:
#                               accuracy balanced_accuracy       recall  \
# RF_MD_red_internal_cv      0.658±0.128       0.643±0.121  0.498±0.197
# RF_ECFP_red_internal_cv    0.667±0.125       0.658±0.128  0.507±0.255
# RF_PT_internal_cv           0.73±0.048         0.72±0.05  0.645±0.087
# RF_PT_red_internal_cv       0.64±0.129       0.629±0.126  0.438±0.245
# RF_MD_internal_cv          0.735±0.047       0.724±0.048  0.645±0.088
# RF_ECFP_internal_cv        0.742±0.043       0.734±0.044  0.669±0.078
# RF_MD_red_internal_test    0.619±0.134       0.591±0.146  0.375±0.305
# RF_ECFP_red_internal_test  0.664±0.161       0.648±0.174   0.55±0.317
# RF_PT_internal_test         0.75±0.049       0.741±0.052  0.671±0.095
# RF_PT_red_internal_test     0.655±0.19       0.633±0.199  0.475±0.309
# RF_MD_internal_test        0.748±0.059       0.737±0.063  0.655±0.118
# RF_ECFP_internal_test      0.753±0.034       0.746±0.032  0.689±0.065
#
#                              precision AU_Prec_Rec_Curve      ROC_AUC  \
# RF_MD_red_internal_cv      0.651±0.206       0.621±0.167  0.664±0.144
# RF_ECFP_red_internal_cv    0.681±0.243       0.635±0.187  0.682±0.146
# RF_PT_internal_cv           0.71±0.075        0.721±0.08  0.767±0.057
# RF_PT_red_internal_cv      0.642±0.252        0.63±0.168   0.671±0.15
# RF_MD_internal_cv           0.719±0.07       0.729±0.061  0.774±0.049
# RF_ECFP_internal_cv         0.722±0.07       0.762±0.067  0.796±0.054
# RF_MD_red_internal_test     0.543±0.35       0.668±0.144  0.709±0.136
# RF_ECFP_red_internal_test  0.605±0.296       0.753±0.194  0.764±0.201
# RF_PT_internal_test        0.732±0.059        0.787±0.08  0.821±0.043
# RF_PT_red_internal_test     0.65±0.346       0.669±0.209   0.66±0.247
# RF_MD_internal_test         0.74±0.073        0.77±0.084  0.813±0.052
# RF_ECFP_internal_test       0.736±0.07       0.822±0.059  0.847±0.038
#
#                                    MCC
# RF_MD_red_internal_cv      0.305±0.248
# RF_ECFP_red_internal_cv    0.341±0.257
# RF_PT_internal_cv          0.447±0.099
# RF_PT_red_internal_cv      0.282±0.254
# RF_MD_internal_cv          0.458±0.097
# RF_ECFP_internal_cv        0.475±0.087
# RF_MD_red_internal_test     0.207±0.33
# RF_ECFP_red_internal_test  0.309±0.376
# RF_PT_internal_test        0.489±0.101
# RF_PT_red_internal_test    0.294±0.425
# RF_MD_internal_test        0.487±0.122
# RF_ECFP_internal_test         0.5±0.07

# %%
RF_test = pd.DataFrame.from_dict(RF_test,orient='index', columns=['accuracy','balanced_accuracy','recall','precision','AU_Prec_Rec_Curve','ROC_AUC','MCC'])
SVM_test = pd.DataFrame.from_dict(SVM_test,orient='index', columns=['accuracy','balanced_accuracy','recall','precision','AU_Prec_Rec_Curve','ROC_AUC','MCC'])

# %% [raw]
# SVM_test.to_csv("./ECFP4_MD_PT_SVM_results_table.csv")
# RF_test.to_csv("./ECFP4_MD_PT_RF_results_table.csv")
